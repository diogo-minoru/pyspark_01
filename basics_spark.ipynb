# %% [markdown]
# ### Iniciando sessão spark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("DemoSpark").getOrCreate()
spark

# %% [markdown]
# ### Leitura do arquivo csv

# %%
path_customer = 'data/customer.csv'
# df_customer = spark.read.csv(path = path_customer, header = True, inferSchema = True)
# df_customer = spark.read.option('delimeter', ',').option('header', True).csv(path = path_customer)
df_customer = spark.read.options(delimeter = ',', header = True).csv(path = path_customer, inferSchema = True)

df_customer.show(5)
# Out:
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# |CustomerKey|GeoAreaKey|   StartDT|     EndDT|Continent|Gender|Title|GivenName|MiddleInitial|     Surname|    StreetAddress|          City|State|        StateFull|ZipCode|Country|CountryFull|  Birthday|Age|          Occupation|            Company|             Vehicle|  Latitude| Longitude|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# |         15|         4|1990-09-10|2034-07-29|Australia|  male|  Mr.|   Julian|            A|    McGuigan|25 Railway Street| Canning Creek|  QLD|       Queensland|   4357|     AU|  Australia|1965-03-24| 55| Border Patrol agent| Cut Rite Lawn Care|2000 Peugeot Kart Up|-27.831694|151.166686|
# |         23|         8|1995-08-11|2045-01-26|Australia|female|  Ms.|     Rose|            H|        Dash|92 Foreshore Road|     Guildford|   WA|Western Australia|   6055|     AU|  Australia|1990-05-10| 30|Agricultural and ...|        Rack N Sack|     2005 Volvo XC90|-31.919733|116.047894|
# |         36|         2|1992-03-12|2044-05-14|Australia|female|  Ms.|Annabelle|            J|    Townsend|     83 Webb Road|Mayfield North|  NSW|  New South Wales|   2304|     AU|  Australia|1964-07-16| 56|Special education...|       id Boutiques|   1999 Lancia Lybra|-32.881778|151.708086|
# |        120|         6|1983-07-23|2033-08-09|Australia|  male|  Mr.|    Jamie|            H|Hetherington|      3 Link Road|       Reekara|  TAS|         Tasmania|   7256|     AU|  Australia|1946-12-11| 74|Dental laboratory...|Showbiz Pizza Place|  2006 Dodge Durango|-39.771044|144.019797|
# |        180|         7|1987-11-26|2026-10-14|Australia|  male|  Mr.|  Gabriel|            P|   Bosanquet| 50 Larissa Court|         Yelta|  VIC|         Victoria|   3505|     AU|  Australia|1955-04-24| 65|Administrative su...| Dubrow's Cafeteria|  1995 Morgan Plus 4|-34.127446|142.144448|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# only showing top 5 rows

# %%
# Mostrar as columas de um dataframe
df_customer.columns

# Selecionando colunas no do dataframe
customer_columns = ['CustomerKey', 'Continent', 'Gender', 'GivenName', 'MiddleInitial', 'Surname', 'City', 'StateFull', 'CountryFull', 'Age']
df_customer.select(customer_columns).show()
# Out:
# +-------+------------------+-------------+------+---------+-------------+-------+------+-------------+-------------+------------------+
# |summary|       CustomerKey|    Continent|Gender|GivenName|MiddleInitial|Surname|  City|    StateFull|  CountryFull|               Age|
# +-------+------------------+-------------+------+---------+-------------+-------+------+-------------+-------------+------------------+
# |  count|            104990|       104990|104990|   104990|       104990| 104990|104990|       104990|       104990|            104990|
# |   mean|1049779.4654538527|         NULL|  NULL|      NaN|          0.0|    NaN|  NULL|         NULL|         NULL|51.896332984093725|
# | stddev| 607914.0568468425|         NULL|  NULL|      NaN|         NULL|    NaN|  NULL|         NULL|         NULL|19.359899289118264|
# |    min|                15|    Australia|female|        0|            0|'t Hoen|  Aach|     Aberdeen|    Australia|                19|
# |    max|           2099743|North America|  male|    Živko|            Ž| Žáková| Ürzig|Île-de-France|United States|                85|
# +-------+------------------+-------------+------+---------+-------------+-------+------+-------------+-------------+------------------+

# %% [markdown]
# ### Mostrar tipos de dados de cada coluna

# %%
df_customer.select(customer_columns).dtypes
# df_customer.select(customer_columns).describe().show()
# df_customer.printSchema()
# Out:
# [('CustomerKey', 'int'),
#  ('Continent', 'string'),
#  ('Gender', 'string'),
#  ('GivenName', 'string'),
#  ('MiddleInitial', 'string'),
#  ('Surname', 'string'),
#  ('City', 'string'),
#  ('StateFull', 'string'),
#  ('CountryFull', 'string'),
#  ('Age', 'int')]

# %% [markdown]
# ### Adicionar e remover colunas

# %%
df_customer = df_customer.withColumn('Age Added by 5', df_customer['Age'] + 5)
df_customer.select('Age Added by 5').show(5)
# Out:
# +--------------+
# |Age Added by 5|
# +--------------+
# |            60|
# |            35|
# |            61|
# |            79|
# |            70|
# +--------------+
# only showing top 5 rows

# %%
df_customer = df_customer.drop('Age Added by 5')
df_customer.show(5)
# Out:
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# |CustomerKey|GeoAreaKey|   StartDT|     EndDT|Continent|Gender|Title|GivenName|MiddleInitial|     Surname|    StreetAddress|          City|State|        StateFull|ZipCode|Country|CountryFull|  Birthday|Age|          Occupation|            Company|             Vehicle|  Latitude| Longitude|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# |         15|         4|1990-09-10|2034-07-29|Australia|  male|  Mr.|   Julian|            A|    McGuigan|25 Railway Street| Canning Creek|  QLD|       Queensland|   4357|     AU|  Australia|1965-03-24| 55| Border Patrol agent| Cut Rite Lawn Care|2000 Peugeot Kart Up|-27.831694|151.166686|
# |         23|         8|1995-08-11|2045-01-26|Australia|female|  Ms.|     Rose|            H|        Dash|92 Foreshore Road|     Guildford|   WA|Western Australia|   6055|     AU|  Australia|1990-05-10| 30|Agricultural and ...|        Rack N Sack|     2005 Volvo XC90|-31.919733|116.047894|
# |         36|         2|1992-03-12|2044-05-14|Australia|female|  Ms.|Annabelle|            J|    Townsend|     83 Webb Road|Mayfield North|  NSW|  New South Wales|   2304|     AU|  Australia|1964-07-16| 56|Special education...|       id Boutiques|   1999 Lancia Lybra|-32.881778|151.708086|
# |        120|         6|1983-07-23|2033-08-09|Australia|  male|  Mr.|    Jamie|            H|Hetherington|      3 Link Road|       Reekara|  TAS|         Tasmania|   7256|     AU|  Australia|1946-12-11| 74|Dental laboratory...|Showbiz Pizza Place|  2006 Dodge Durango|-39.771044|144.019797|
# |        180|         7|1987-11-26|2026-10-14|Australia|  male|  Mr.|  Gabriel|            P|   Bosanquet| 50 Larissa Court|         Yelta|  VIC|         Victoria|   3505|     AU|  Australia|1955-04-24| 65|Administrative su...| Dubrow's Cafeteria|  1995 Morgan Plus 4|-34.127446|142.144448|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# only showing top 5 rows

# %% [markdown]
# ### Renomear a Coluna

# %%
# df_customer.withColumnRenamed('StartDT', 'StartDate').show()
df_customer.withColumnsRenamed({'StartDT': 'StartDate', 'EndDT': 'EndDate'}).show(5)
# Out:
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# |CustomerKey|GeoAreaKey| StartDate|   EndDate|Continent|Gender|Title|GivenName|MiddleInitial|     Surname|    StreetAddress|          City|State|        StateFull|ZipCode|Country|CountryFull|  Birthday|Age|          Occupation|            Company|             Vehicle|  Latitude| Longitude|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# |         15|         4|1990-09-10|2034-07-29|Australia|  male|  Mr.|   Julian|            A|    McGuigan|25 Railway Street| Canning Creek|  QLD|       Queensland|   4357|     AU|  Australia|1965-03-24| 55| Border Patrol agent| Cut Rite Lawn Care|2000 Peugeot Kart Up|-27.831694|151.166686|
# |         23|         8|1995-08-11|2045-01-26|Australia|female|  Ms.|     Rose|            H|        Dash|92 Foreshore Road|     Guildford|   WA|Western Australia|   6055|     AU|  Australia|1990-05-10| 30|Agricultural and ...|        Rack N Sack|     2005 Volvo XC90|-31.919733|116.047894|
# |         36|         2|1992-03-12|2044-05-14|Australia|female|  Ms.|Annabelle|            J|    Townsend|     83 Webb Road|Mayfield North|  NSW|  New South Wales|   2304|     AU|  Australia|1964-07-16| 56|Special education...|       id Boutiques|   1999 Lancia Lybra|-32.881778|151.708086|
# |        120|         6|1983-07-23|2033-08-09|Australia|  male|  Mr.|    Jamie|            H|Hetherington|      3 Link Road|       Reekara|  TAS|         Tasmania|   7256|     AU|  Australia|1946-12-11| 74|Dental laboratory...|Showbiz Pizza Place|  2006 Dodge Durango|-39.771044|144.019797|
# |        180|         7|1987-11-26|2026-10-14|Australia|  male|  Mr.|  Gabriel|            P|   Bosanquet| 50 Larissa Court|         Yelta|  VIC|         Victoria|   3505|     AU|  Australia|1955-04-24| 65|Administrative su...| Dubrow's Cafeteria|  1995 Morgan Plus 4|-34.127446|142.144448|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+-----------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+-------------------+--------------------+----------+----------+
# only showing top 5 rows

# %% [markdown]
# ### Mostrar linhas nulas

# %%
from pyspark.sql.functions import col
from functools import reduce

condition = reduce(lambda a, b: a | b, [col(c).isNull() for c in df_customer.columns])
null_rows_df = df_customer.filter(condition)
null_rows_df.show()
# Out:
# +-----------+----------+----------+----------+-------------+------+-----+---------+-------------+-----------------+--------------------+-----------------+-----+------------------+-------+-------+-----------+----------+---+--------------------+-------+--------------------+----------+----------+
# |CustomerKey|GeoAreaKey|   StartDT|     EndDT|    Continent|Gender|Title|GivenName|MiddleInitial|          Surname|       StreetAddress|             City|State|         StateFull|ZipCode|Country|CountryFull|  Birthday|Age|          Occupation|Company|             Vehicle|  Latitude| Longitude|
# +-----------+----------+----------+----------+-------------+------+-----+---------+-------------+-----------------+--------------------+-----------------+-----+------------------+-------+-------+-----------+----------+---+--------------------+-------+--------------------+----------+----------+
# |       5720|         2|1981-06-26|2018-11-27|    Australia|  male|  Mr.|   Bailey|            G|          Bracker|      86 Ugoa Street|     Mount George|  NSW|   New South Wales|   2424|     AU|  Australia|1981-03-04| 39|Electronic typese...|   NULL|  2007 Dodge Caravan|-31.599948|151.962429|
# |      18236|         2|1992-09-20|2036-06-21|    Australia|  male|  Mr.|   Xavier|            E|            Dunne|  57 Dalgarno Street|              Nea|  NSW|   New South Wales|   2381|     AU|  Australia|1998-05-06| 22|   Coding specialist|   NULL|    2008 Lotus Elise|-31.165915|150.464875|
# |      28491|         4|1991-10-14|2039-12-23|    Australia|female|  Dr.|   Tahlia|            S|     Van De Velde|54 Glen William Road|         Bolwarra|  QLD|        Queensland|   4871|     AU|  Australia|1962-10-25| 58|           Architect|   NULL|  2002 Smart ForFour|-16.193522|143.168325|
# |      29732|         4|1986-05-15|2018-11-26|    Australia|  male|  Mr.|  Matthew|            M|         Grimmett|      83 Lowe Street|       Myall Park|  QLD|        Queensland|   4415|     AU|  Australia|1953-04-21| 67|    Oxygen therapist|   NULL|  1998 Bentley Turbo|-26.501935|150.115399|
# |      34572|         2|1993-05-16|2027-08-24|    Australia|  male|  Mr.|     Finn|            A|          Perkins|     97 Yangan Drive|         Ironbark|  NSW|   New South Wales|   2347|     AU|  Australia|1942-01-26| 79|Professional prop...|   NULL|      1999 Volvo S80|-30.245245|150.666079|
# |      57665|         4|1994-03-17|2044-01-04|    Australia|female| Mrs.|     Kate|            A|          Whittle|     73 Ferny Avenue|          Elliott|  QLD|        Queensland|   4670|     AU|  Australia|1991-03-29| 29|Locker room atten...|   NULL|    2005 Pontiac GTO|-24.966843|152.289217|
# |      61691|         2|1980-01-10|2042-01-09|    Australia|female|  Ms.| Isabella|            C|            Curmi|    6 Ulomogo Street|           Toongi|  NSW|   New South Wales|   2830|     AU|  Australia|1957-06-07| 63|     General manager|   NULL|  1994 Ford Windstar|-32.282436|148.543477|
# |      64998|         7|1986-12-01|2043-08-04|    Australia|female|  Ms.| Scarlett|            Z|           Frazer|    2 Fitzroy Street|        Delacombe|  VIC|          Victoria|   3356|     AU|  Australia|1986-10-01| 34|           Historian|   NULL|  2005 Ford Econovan|-37.629047|143.823276|
# |      69102|         2|1981-04-22|2019-09-09|    Australia|  male|  Mr.|      Kai|            A|           Brough|      51 Bass Street|        Blue Knob|  NSW|   New South Wales|   2480|     AU|  Australia|1944-05-01| 76|      Skills trainer|   NULL|  2004 Toyota Previa|-28.703214| 153.26401|
# +-----------+----------+----------+----------+-------------+------+-----+---------+-------------+-----------------+--------------------+-----------------+-----+------------------+-------+-------+-----------+----------+---+--------------------+-------+--------------------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Remover linhas com qualquer valor nulo

# %%
# Remove toda a linha que qualquer (any) coluna estiver nula, no mínimo duas colunas precisam estar não nulas
df_customer.na.drop(
    how = 'any',
    #thresh = 2,
    subset = ['Age'] # Apenas se a coluna age tiver nula
    ).show()
# Out:
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+--------------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+--------------------+--------------------+----------+----------+
# |CustomerKey|GeoAreaKey|   StartDT|     EndDT|Continent|Gender|Title|GivenName|MiddleInitial|     Surname|       StreetAddress|          City|State|        StateFull|ZipCode|Country|CountryFull|  Birthday|Age|          Occupation|             Company|             Vehicle|  Latitude| Longitude|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+--------------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+--------------------+--------------------+----------+----------+
# |         15|         4|1990-09-10|2034-07-29|Australia|  male|  Mr.|   Julian|            A|    McGuigan|   25 Railway Street| Canning Creek|  QLD|       Queensland|   4357|     AU|  Australia|1965-03-24| 55| Border Patrol agent|  Cut Rite Lawn Care|2000 Peugeot Kart Up|-27.831694|151.166686|
# |         23|         8|1995-08-11|2045-01-26|Australia|female|  Ms.|     Rose|            H|        Dash|   92 Foreshore Road|     Guildford|   WA|Western Australia|   6055|     AU|  Australia|1990-05-10| 30|Agricultural and ...|         Rack N Sack|     2005 Volvo XC90|-31.919733|116.047894|
# |         36|         2|1992-03-12|2044-05-14|Australia|female|  Ms.|Annabelle|            J|    Townsend|        83 Webb Road|Mayfield North|  NSW|  New South Wales|   2304|     AU|  Australia|1964-07-16| 56|Special education...|        id Boutiques|   1999 Lancia Lybra|-32.881778|151.708086|
# |        120|         6|1983-07-23|2033-08-09|Australia|  male|  Mr.|    Jamie|            H|Hetherington|         3 Link Road|       Reekara|  TAS|         Tasmania|   7256|     AU|  Australia|1946-12-11| 74|Dental laboratory...| Showbiz Pizza Place|  2006 Dodge Durango|-39.771044|144.019797|
# |        180|         7|1987-11-26|2026-10-14|Australia|  male|  Mr.|  Gabriel|            P|   Bosanquet|    50 Larissa Court|         Yelta|  VIC|         Victoria|   3505|     AU|  Australia|1955-04-24| 65|Administrative su...|  Dubrow's Cafeteria|  1995 Morgan Plus 4|-34.127446|142.144448|
# |        185|         2|1990-08-01|2029-05-28|Australia|female| Mrs.|Gabrielle|            B|    Castella|74 Old Tenterfiel...|   Mallanganee|  NSW|  New South Wales|   2469|     AU|  Australia|1980-02-23| 40|Management dietitian|            d.e.m.o.|      1997 Alpina B6| -29.01286| 152.83917|
# |        189|         7|2008-07-05|2017-11-01|Australia|female|  Ms.|   Hayley|            C|        Jull|  61 McKillop Street|   Rocky Point|  VIC|         Victoria|   3377|     AU|  Australia|1960-04-18| 60|            Sculptor|          Asian Plan|      2006 Alpina B5|-37.339425|142.912375|
# |        501|         4|2005-11-22|2027-03-01|Australia|  male|  Mr.|   Elijah|            G|     England|   51 Hay Point Road|       Ooralea|  QLD|       Queensland|   4740|     AU|  Australia|1990-04-13| 30|  Medical geographer|Wheels Discount Auto|  1997 Oldsmobile SS|-21.267601|149.075727|
# |        505|         2|1985-11-05|2044-11-06|Australia|female| Mrs.|Elizabeth|            J|       Verge|  59 Edgewater Close|    Tapitallee|  NSW|  New South Wales|   2540|     AU|  Australia|1958-06-24| 62|Veterinary techni...|        Exact Realty| 1992 Chrysler Viper|-34.983796|150.590348|
# +-----------+----------+----------+----------+---------+------+-----+---------+-------------+------------+--------------------+--------------+-----+-----------------+-------+-------+-----------+----------+---+--------------------+--------------------+--------------------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Preencher valores nulos

# %%
df_customer.na.fill('Não Informado', subset = ['Company', 'Vehicle']).filter(df_customer['Company'].isNull()).show()
# Out:
# +-----------+----------+----------+----------+-------------+------+-----+---------+-------------+-----------------+--------------------+-----------------+-----+------------------+-------+-------+-----------+----------+---+--------------------+-------------+--------------------+----------+----------+
# |CustomerKey|GeoAreaKey|   StartDT|     EndDT|    Continent|Gender|Title|GivenName|MiddleInitial|          Surname|       StreetAddress|             City|State|         StateFull|ZipCode|Country|CountryFull|  Birthday|Age|          Occupation|      Company|             Vehicle|  Latitude| Longitude|
# +-----------+----------+----------+----------+-------------+------+-----+---------+-------------+-----------------+--------------------+-----------------+-----+------------------+-------+-------+-----------+----------+---+--------------------+-------------+--------------------+----------+----------+
# |       5720|         2|1981-06-26|2018-11-27|    Australia|  male|  Mr.|   Bailey|            G|          Bracker|      86 Ugoa Street|     Mount George|  NSW|   New South Wales|   2424|     AU|  Australia|1981-03-04| 39|Electronic typese...|Não Informado|  2007 Dodge Caravan|-31.599948|151.962429|
# |      18236|         2|1992-09-20|2036-06-21|    Australia|  male|  Mr.|   Xavier|            E|            Dunne|  57 Dalgarno Street|              Nea|  NSW|   New South Wales|   2381|     AU|  Australia|1998-05-06| 22|   Coding specialist|Não Informado|    2008 Lotus Elise|-31.165915|150.464875|
# |      28491|         4|1991-10-14|2039-12-23|    Australia|female|  Dr.|   Tahlia|            S|     Van De Velde|54 Glen William Road|         Bolwarra|  QLD|        Queensland|   4871|     AU|  Australia|1962-10-25| 58|           Architect|Não Informado|  2002 Smart ForFour|-16.193522|143.168325|
# |      29732|         4|1986-05-15|2018-11-26|    Australia|  male|  Mr.|  Matthew|            M|         Grimmett|      83 Lowe Street|       Myall Park|  QLD|        Queensland|   4415|     AU|  Australia|1953-04-21| 67|    Oxygen therapist|Não Informado|  1998 Bentley Turbo|-26.501935|150.115399|
# |      34572|         2|1993-05-16|2027-08-24|    Australia|  male|  Mr.|     Finn|            A|          Perkins|     97 Yangan Drive|         Ironbark|  NSW|   New South Wales|   2347|     AU|  Australia|1942-01-26| 79|Professional prop...|Não Informado|      1999 Volvo S80|-30.245245|150.666079|
# |      57665|         4|1994-03-17|2044-01-04|    Australia|female| Mrs.|     Kate|            A|          Whittle|     73 Ferny Avenue|          Elliott|  QLD|        Queensland|   4670|     AU|  Australia|1991-03-29| 29|Locker room atten...|Não Informado|    2005 Pontiac GTO|-24.966843|152.289217|
# |     214557|        19|1981-04-21|2030-08-19|North America|female| Mrs.| Patricia|            A|            Mason|      121 rue Boulay|St Simon De Bagot|   QC|            Quebec|J0H 1Y0|     CA|     Canada|1972-05-14| 48|Oral and maxillof...|Não Informado|2004 Ferrari Supe...| 45.659423|-72.856435|
# |     236755|        17|1994-12-29|2021-12-04|North America|  male|  Mr.|  William|            J|            Bilbo|     2125 Bay Street|          Toronto|   ON|           Ontario|M5J 2R8|     CA|     Canada|1956-10-02| 64|          Log marker|Não Informado|1994 Mitsubishi 3...| 43.606685|-79.366583|
# +-----------+----------+----------+----------+-------------+------+-----+---------+-------------+-----------------+--------------------+-----------------+-----+------------------+-------+-------+-----------+----------+---+--------------------+-------------+--------------------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Filtrando valores

# %%
df_customer.select(['CustomerKey', 'GivenName', 'Age']).filter('Age > 50').show(5)
# Out:
# +-----------+---------+---+
# |CustomerKey|GivenName|Age|
# +-----------+---------+---+
# |         15|   Julian| 55|
# |         36|Annabelle| 56|
# |        120|    Jamie| 74|
# |        180|  Gabriel| 65|
# |        189|   Hayley| 60|
# +-----------+---------+---+
# only showing top 5 rows

# %%
df_customer.select(['CustomerKey', 'GivenName', 'Age']).filter(~(df_customer['Age'] > 50) & (df_customer['GivenName'] == 'Julian')).show(5)
# Out:
# +-----------+---------+---+
# |CustomerKey|GivenName|Age|
# +-----------+---------+---+
# |       3429|   Julian| 20|
# |      13975|   Julian| 34|
# |      30989|   Julian| 45|
# |      37298|   Julian| 20|
# |      43278|   Julian| 33|
# +-----------+---------+---+
# only showing top 5 rows

# %% [markdown]
# ### Agrupamento e agragações

# %%
# from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName('Demo').getOrCreate()

# %%
path_orderrows = 'data/orderrows.csv'
df_orderrows = spark.read.csv(path_orderrows, header = True, inferSchema = True)
df_orderrows.show(5)
# Out:
# +--------+----------+----------+--------+---------+--------+--------+
# |OrderKey|LineNumber|ProductKey|Quantity|UnitPrice|NetPrice|UnitCost|
# +--------+----------+----------+--------+---------+--------+--------+
# |  139000|         0|       153|       2|  375.976| 375.976| 172.896|
# |  139000|         1|      1621|       8|    7.794|   7.794|   3.972|
# |  139001|         0|       279|       3|    239.2|  227.24| 121.952|
# |  139001|         1|      1806|       1|     22.4|    22.4|  11.417|
# |  139002|         0|       125|       2|   114.72| 103.248|  58.488|
# +--------+----------+----------+--------+---------+--------+--------+
# only showing top 5 rows

# %%
# Adicionando coluna de TotalCost e TotalNetPrice
df_orderrows = df_orderrows.withColumns(
    {'TotalCost': df_orderrows['Quantity'] * df_orderrows['UnitCost'],
     'TotalNetPrice': df_orderrows['Quantity'] * df_orderrows['NetPrice']}
)

df_orderrows = df_orderrows.withColumn('TotalProfit', df_orderrows['TotalNetPrice'] - df_orderrows['TotalCost'])
df_orderrows.show()
# Out:
# +--------+----------+----------+--------+---------+--------+--------+------------------+-----------------+------------------+
# |OrderKey|LineNumber|ProductKey|Quantity|UnitPrice|NetPrice|UnitCost|         TotalCost|    TotalNetPrice|       TotalProfit|
# +--------+----------+----------+--------+---------+--------+--------+------------------+-----------------+------------------+
# |  139000|         0|       153|       2|  375.976| 375.976| 172.896|           345.792|          751.952|            406.16|
# |  139000|         1|      1621|       8|    7.794|   7.794|   3.972|            31.776|           62.352|30.575999999999997|
# |  139001|         0|       279|       3|    239.2|  227.24| 121.952|           365.856|           681.72|315.86400000000003|
# |  139001|         1|      1806|       1|     22.4|    22.4|  11.417|            11.417|             22.4|10.982999999999999|
# |  139002|         0|       125|       2|   114.72| 103.248|  58.488|           116.976|          206.496| 89.52000000000001|
# |  139002|         1|       157|       1|  879.992| 879.992|  404.68|            404.68|          879.992|475.31199999999995|
# |  139002|         2|        55|       5|    222.0|   222.0| 73.5525|          367.7625|           1110.0|          742.2375|
# |  139002|         3|        43|       6|    174.0|   174.0| 80.0175|           480.105|           1044.0|           563.895|
# |  139002|         5|      2361|       1|  82.4925|74.24325|   42.06|             42.06|         74.24325|          32.18325|
# |  139002|         6|      2043|       2|  499.455|439.5204|  165.48|            330.96|         879.0408|          548.0808|
# |  139003|         0|      1618|       1|   35.394|  35.394|  16.278|            16.278|           35.394|            19.116|
# |  139003|         1|      1433|       6|    554.4| 487.872| 254.952|          1529.712|         2927.232|           1397.52|
# |  139003|         2|       440|       2|  549.875|494.8875|  280.35|             560.7|          989.775|429.07499999999993|
# |  139003|         3|      1624|       2|    131.4| 116.946|  43.536|            87.072|          233.892|            146.82|
# |  139003|         4|       960|       8|    236.8| 206.016| 108.896|           871.168|         1648.128| 776.9599999999999|
# |  139003|         5|      1630|       2|   13.734|  13.734|   4.548|             9.096|           27.468|            18.372|
# |  139004|         0|      1499|       1|    558.0|  513.36| 256.608|           256.608|           513.36|           256.752|
# |  139005|         0|      1147|       1|   1048.0|  1048.0| 481.936|           481.936|           1048.0| 566.0640000000001|
# |  139005|         1|      1775|       2|     30.1|  26.488|  15.344|            30.688|           52.976|            22.288|
# |  139005|         2|      2118|       3|   333.75|290.3625|  153.48|460.43999999999994|871.0875000000001|410.64750000000015|
# +--------+----------+----------+--------+---------+--------+--------+------------------+-----------------+------------------+
# only showing top 20 rows

# %%
df_orderrows.groupBy(['OrderKey', 'ProductKey']).sum('TotalProfit').orderBy(3, ascending = False).show()
# Out:
# +--------+----------+------------------+
# |OrderKey|ProductKey|  sum(TotalProfit)|
# +--------+----------+------------------+
# | 1477041|       600|           33420.6|
# | 1377023|       540|           33420.6|
# | 1272006|       564|           33420.6|
# |  410008|       575|           30692.4|
# | 1241025|       551|           30692.4|
# | 1395030|       564|29422.199999999997|
# | 1234036|       588|           28422.6|
# |  677001|       575|          28332.45|
# | 1741006|       633|          27623.16|
# |  775007|       633|          26855.85|
# | 1166002|       588|          26736.48|
# | 1510020|       540|          26736.48|
# | 1456003|       623|25580.339999999997|
# | 1127017|       551|24731.459999999995|
# | 1197005|       551|          24553.92|
# | 1001016|       611|          24553.92|
# | 1391017|       575|          24553.92|
# |  658000|       633|           24446.1|
# | 2318020|       588|24315.750000000004|
# |  524003|       551|           24266.4|
# +--------+----------+------------------+
# only showing top 20 rows
